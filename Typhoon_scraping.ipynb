# %%
import urllib.request
from bs4 import BeautifulSoup
import re
import numpy as np
import datetime
import unicodedata
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import time
import json
import os

from tqdm import tqdm_notebook as tqdm
from ipywidgets import IntProgress

# %%
url = "http://agora.ex.nii.ac.jp/digital-typhoon/search_date.html"
nem = urllib.request.urlopen(url).read()
soup = BeautifulSoup(nem,"html.parser")

# %%
years1 = soup.find_all('td',class_='LISTING1')
years2 = soup.find_all('td',class_='LISTING0')

# %%
y1 = [i.text.replace('\n','').replace('年','') for i in years1][:35]
y2 = [i.text.replace('\n','').replace('年','') for i in years2][:34]
years = []
for i,j in zip(y1, y2):
    years.append(i)
    years.append(j)

# %%
url1 = [i.find('a').attrs['href'] for i in years1[:35]]
url2 = [i.find('a').attrs['href'] for i in years2[:34]]
urls = []
for i,j in zip(url1, url2):
    urls.append(i)
    urls.append(j)

# %%
years.append('2019')
urls.append('/digital-typhoon/year/wnp/2019.html.ja')

# %%
def TransDate(string):
    hoge, fuga = string.split(' ')
    year, month, day = hoge.split('-')
    hour, minute = fuga.split(':')
    summary = datetime.datetime(int(year),int(month),int(day),int(hour),int(minute))
    return summary

def TransDelta(string):
    day,hour = string.split('日')
    hour = hour.replace('時間','')
    return datetime.timedelta(hours=int(hour),days=int(day))

# %%
dic_array = {}
for u,y in zip(tqdm(urls[26:]),years[26:]):
    url = "http://agora.ex.nii.ac.jp"+u
    nem = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(nem,"html.parser")
    table_rows1 = soup.find_all('tr',class_='ROW1')
    table_rows2 = soup.find_all('tr',class_='ROW0')
    table_rows = []
    for r1,r2 in zip(table_rows1, table_rows2):
        table_rows.append(r1)
        table_rows.append(r2)
    if(len(table_rows1) > len(table_rows2)):
        table_rows.append(table_rows1[-1])
        
    os.mkdir('typhoon/'+str(y))
    
    dic = {y:[]}
    for row in table_rows:
        columns = row.find_all('td')
        birth = TransDate(columns[4].text)
        death = TransDate(columns[5].text)
        duration = TransDelta(columns[6].text)
        hPa = float(columns[7].text)
        
        url_low = columns[1].find('a').get('href')
        url_low = "http://agora.ex.nii.ac.jp"+url_low
        nem1 = urllib.request.urlopen(url_low).read()
        soup1 = BeautifulSoup(nem1,"html.parser")
        table = soup1.find_all('table',class_='METATAB')[0]
        tr = table.find_all('tr')
        wind = tr[12].text.replace(' (knots)\n\t', '')
        area1 = re.sub('\(km\)|\n| ', '', tr[14].text.split('\t')[2])
        area2 = re.sub('\(km\)|\n| ', '', tr[18].text.split('\t')[2])
        moving = re.sub('\(km\)|\n|\t| ', '', tr[22].text)
        mean_velocity = re.sub('\(km/h\)| ', '', tr[24].text.split('|')[0])
        ACE = tr[30].text
        
        d = {'birth': birth, 'death': death, 
             'duration': duration, 'pressure': hPa,
             'wind_velocity': float(wind), 'area1': float(area1),
             'area2': float(area2), 'moving': float(moving), 
             'mean_velocity':float(mean_velocity), 'ACE':float(ACE)}
        
        dic[y].append(d)
    
        num = str(columns[1].text)
        json_url = 'http://agora.ex.nii.ac.jp/digital-typhoon/geojson/wnp/'+num+'.ja.json'
        response = urllib.request.urlopen(json_url)
        content = json.loads(response.read().decode('utf8'))
        f = open("typhoon/"+str(y)+"/"+num+".json", "w")
        json.dump(content, f)
        f.close()
    
    dic_array.update(dic)
# Out:
# HBox(children=(IntProgress(value=0, max=43), HTML(value='')))

# %%
dic_array = np.array([dic_array])
np.save('typhoon/dataset.npy',dic_array)

# %%
dic_array[0]['1981']
# Out:
# [{'birth': datetime.datetime(1981, 3, 12, 12, 0),
#   'death': datetime.datetime(1981, 3, 18, 6, 0),
#   'duration': datetime.timedelta(5, 64800),
#   'pressure': 945.0,
#   'wind_velocity': 90.0,
#   'area1': 230.0,
#   'area2': 460.0,
#   'moving': 3564.0,
#   'mean_velocity': 25.8,
#   'ACE': 105800.0},
#  {'birth': datetime.datetime(1981, 4, 15, 18, 0),
#   'death': datetime.datetime(1981, 4, 20, 12, 0),
#   'duration': datetime.timedelta(4, 64800),
#   'pressure': 980.0,
#   'wind_velocity': 60.0,
#   'area1': 90.0,
#   'area2': 370.0,
#   'moving': 1716.0,
#   'mean_velocity': 15.1,
#   'ACE': 43975.0},
#  {'birth': datetime.datetime(1981, 4, 30, 12, 0),
#   'death': datetime.datetime(1981, 5, 6, 6, 0),
#   'duration': datetime.timedelta(5, 64800),
#   'pressure': 996.0,
#   'wind_velocity': 45.0,
#   'area1': 0.0,
#   'area2': 170.0,
#   'moving': 1408.0,
#   'mean_velocity': 10.2,
#   'ACE': 37800.0},
#  {'birth': datetime.datetime(1981, 6, 9, 0, 0),
#   'death': datetime.datetime(1981, 6, 14, 18, 0),
#   'duration': datetime.timedelta(5, 64800),
#   'pressure': 965.0,
#   'wind_velocity': 60.0,
#   'area1': 110.0,
#   'area2': 460.0,
#   'moving': 2124.0,
#   'mean_velocity': 15.4,
#   'ACE': 50025.0},
#  {'birth': datetime.datetime(1981, 6, 17, 12, 0),
#   'death': datetime.datetime(1981, 6, 22, 18, 0),
#   'duration': datetime.timedelta(5, 21600),
#   'pressure': 965.0,
#   'wind_velocity': 70.0,
#   'area1': 230.0,
#   'area2': 460.0,
#   'moving': 3148.0,
#   'mean_velocity': 25.0,
#   'ACE': 65850.0},
#  {'birth': datetime.datetime(1981, 6, 30, 12, 0),
#   'death': datetime.datetime(1981, 7, 5, 0, 0),
#   'duration': datetime.timedelta(4, 43200),
#   'pressure': 975.0,
#   'wind_velocity': 60.0,
#   'area1': 90.0,
#   'area2': 560.0,
#   'moving': 2248.0,
#   'mean_velocity': 20.8,
#   'ACE': 45175.0},
#  {'birth': datetime.datetime(1981, 7, 3, 6, 0),
#   'death': datetime.datetime(1981, 7, 7, 6, 0),
#   'duration': datetime.timedelta(4),
#   'pressure': 985.0,
#   'wind_velocity': 55.0,
#   'area1': 190.0,
#   'area2': 460.0,
#   'moving': 1851.0,
#   'mean_velocity': 19.3,
#   'ACE': 36800.0},
#  {'birth': datetime.datetime(1981, 7, 18, 0, 0),
#   'death': datetime.datetime(1981, 7, 20, 0, 0),
#   'duration': datetime.timedelta(2),
#   'pressure': 985.0,
#   'wind_velocity': 50.0,
#   'area1': 0.0,
#   'area2': 560.0,
#   'moving': 1163.0,
#   'mean_velocity': 24.2,
#   'ACE': 17625.0},
#  {'birth': datetime.datetime(1981, 7, 22, 12, 0),
#   'death': datetime.datetime(1981, 7, 23, 6, 0),
#   'duration': datetime.timedelta(0, 64800),
#   'pressure': 992.0,
#   'wind_velocity': 40.0,
#   'area1': 0.0,
#   'area2': 460.0,
#   'moving': 216.0,
#   'mean_velocity': 12.0,
#   'ACE': 4800.0},
#  {'birth': datetime.datetime(1981, 7, 28, 6, 0),
#   'death': datetime.datetime(1981, 7, 31, 0, 0),
#   'duration': datetime.timedelta(2, 64800),
#   'pressure': 975.0,
#   'wind_velocity': 50.0,
#   'area1': 0.0,
#   'area2': 370.0,
#   'moving': 1776.0,
#   'mean_velocity': 26.9,
#   'ACE': 21675.0},
#  {'birth': datetime.datetime(1981, 8, 1, 12, 0),
#   'death': datetime.datetime(1981, 8, 2, 18, 0),
#   'duration': datetime.timedelta(1, 21600),
#   'pressure': 990.0,
#   'wind_velocity': 40.0,
#   'area1': 0.0,
#   'area2': 460.0,
#   'moving': 479.0,
#   'mean_velocity': 16.0,
#   'ACE': 8000.0},
#  {'birth': datetime.datetime(1981, 8, 3, 0, 0),
#   'death': datetime.datetime(1981, 8, 5, 18, 0),
#   'duration': datetime.timedelta(2, 64800),
#   'pressure': 975.0,
#   'wind_velocity': 55.0,
#   'area1': 280.0,
#   'area2': 560.0,
#   'moving': 1824.0,
#   'mean_velocity': 27.6,
#   'ACE': 23750.0},
#  {'birth': datetime.datetime(1981, 8, 5, 0, 0),
#   'death': datetime.datetime(1981, 8, 7, 12, 0),
#   'duration': datetime.timedelta(2, 43200),
#   'pressure': 985.0,
#   'wind_velocity': 45.0,
#   'area1': 0.0,
#   'area2': 370.0,
#   'moving': 835.0,
#   'mean_velocity': 13.9,
#   'ACE': 16625.0},
#  {'birth': datetime.datetime(1981, 8, 8, 0, 0),
#   'death': datetime.datetime(1981, 8, 13, 0, 0),
#   'duration': datetime.timedelta(5),
#   'pressure': 980.0,
#   'wind_velocity': 60.0,
#   'area1': 110.0,
#   'area2': 560.0,
#   'moving': 2012.0,
#   'mean_velocity': 16.8,
#   'ACE': 47950.0},
#  {'birth': datetime.datetime(1981, 8, 16, 6, 0),
#   'death': datetime.datetime(1981, 8, 23, 12, 0),
#   'duration': datetime.timedelta(7, 21600),
#   'pressure': 955.0,
#   'wind_velocity': 70.0,
#   'area1': 280.0,
#   'area2': 650.0,
#   'moving': 3334.0,
#   'mean_velocity': 19.2,
#   'ACE': 119080.0},
#  {'birth': datetime.datetime(1981, 8, 17, 6, 0),
#   'death': datetime.datetime(1981, 8, 20, 0, 0),
#   'duration': datetime.timedelta(2, 64800),
#   'pressure': 980.0,
#   'wind_velocity': 50.0,
#   'area1': 0.0,
#   'area2': 370.0,
#   'moving': 1539.0,
#   'mean_velocity': 23.3,
#   'ACE': 21150.0},
#  {'birth': datetime.datetime(1981, 8, 18, 18, 0),
#   'death': datetime.datetime(1981, 8, 19, 6, 0),
#   'duration': datetime.timedelta(0, 43200),
#   'pressure': 994.0,
#   'wind_velocity': 35.0,
#   'area1': 0.0,
#   'area2': 190.0,
#   'moving': 147.0,
#   'mean_velocity': 12.3,
#   'ACE': 2450.0},
#  {'birth': datetime.datetime(1981, 8, 27, 0, 0),
#   'death': datetime.datetime(1981, 9, 3, 18, 0),
#   'duration': datetime.timedelta(7, 64800),
#   'pressure': 950.0,
#   'wind_velocity': 80.0,
#   'area1': 280.0,
#   'area2': 750.0,
#   'moving': 3543.0,
#   'mean_velocity': 19.1,
#   'ACE': 123700.0},
#  {'birth': datetime.datetime(1981, 9, 3, 12, 0),
#   'death': datetime.datetime(1981, 9, 7, 6, 0),
#   'duration': datetime.timedelta(3, 64800),
#   'pressure': 960.0,
#   'wind_velocity': 75.0,
#   'area1': 230.0,
#   'area2': 460.0,
#   'moving': 2727.0,
#   'mean_velocity': 30.3,
#   'ACE': 58325.0},
#  {'birth': datetime.datetime(1981, 9, 16, 0, 0),
#   'death': datetime.datetime(1981, 9, 22, 6, 0),
#   'duration': datetime.timedelta(6, 21600),
#   'pressure': 925.0,
#   'wind_velocity': 100.0,
#   'area1': 280.0,
#   'area2': 560.0,
#   'moving': 2636.0,
#   'mean_velocity': 17.6,
#   'ACE': 118650.0},
#  {'birth': datetime.datetime(1981, 9, 20, 6, 0),
#   'death': datetime.datetime(1981, 9, 23, 18, 0),
#   'duration': datetime.timedelta(3, 43200),
#   'pressure': 965.0,
#   'wind_velocity': 70.0,
#   'area1': 190.0,
#   'area2': 460.0,
#   'moving': 1910.0,
#   'mean_velocity': 22.7,
#   'ACE': 48775.0},
#  {'birth': datetime.datetime(1981, 9, 25, 6, 0),
#   'death': datetime.datetime(1981, 10, 2, 18, 0),
#   'duration': datetime.timedelta(7, 43200),
#   'pressure': 895.0,
#   'wind_velocity': 120.0,
#   'area1': 280.0,
#   'area2': 750.0,
#   'moving': 5017.0,
#   'mean_velocity': 27.9,
#   'ACE': 260180.0},
#  {'birth': datetime.datetime(1981, 10, 13, 18, 0),
#   'death': datetime.datetime(1981, 10, 14, 18, 0),
#   'duration': datetime.timedelta(1),
#   'pressure': 994.0,
#   'wind_velocity': 45.0,
#   'area1': 0.0,
#   'area2': 190.0,
#   'moving': 673.0,
#   'mean_velocity': 28.0,
#   'ACE': 6825.0},
#  {'birth': datetime.datetime(1981, 10, 15, 18, 0),
#   'death': datetime.datetime(1981, 10, 23, 6, 0),
#   'duration': datetime.timedelta(7, 43200),
#   'pressure': 950.0,
#   'wind_velocity': 85.0,
#   'area1': 600.0,
#   'area2': 1100.0,
#   'moving': 5162.0,
#   'mean_velocity': 28.7,
#   'ACE': 147120.0},
#  {'birth': datetime.datetime(1981, 11, 14, 18, 0),
#   'death': datetime.datetime(1981, 11, 22, 0, 0),
#   'duration': datetime.timedelta(7, 21600),
#   'pressure': 955.0,
#   'wind_velocity': 70.0,
#   'area1': 140.0,
#   'area2': 560.0,
#   'moving': 4262.0,
#   'mean_velocity': 24.5,
#   'ACE': 86275.0},
#  {'birth': datetime.datetime(1981, 11, 19, 6, 0),
#   'death': datetime.datetime(1981, 11, 27, 0, 0),
#   'duration': datetime.timedelta(7, 64800),
#   'pressure': 905.0,
#   'wind_velocity': 110.0,
#   'area1': 280.0,
#   'area2': 650.0,
#   'moving': 4432.0,
#   'mean_velocity': 23.8,
#   'ACE': 168250.0},
#  {'birth': datetime.datetime(1981, 11, 23, 0, 0),
#   'death': datetime.datetime(1981, 11, 24, 6, 0),
#   'duration': datetime.timedelta(1, 21600),
#   'pressure': 1000.0,
#   'wind_velocity': 40.0,
#   'area1': 0.0,
#   'area2': 110.0,
#   'moving': 937.0,
#   'mean_velocity': 31.2,
#   'ACE': 6500.0},
#  {'birth': datetime.datetime(1981, 12, 11, 6, 0),
#   'death': datetime.datetime(1981, 12, 20, 18, 0),
#   'duration': datetime.timedelta(9, 43200),
#   'pressure': 925.0,
#   'wind_velocity': 100.0,
#   'area1': 280.0,
#   'area2': 950.0,
#   'moving': 2587.0,
#   'mean_velocity': 11.4,
#   'ACE': 197320.0},
#  {'birth': datetime.datetime(1981, 12, 23, 12, 0),
#   'death': datetime.datetime(1981, 12, 28, 6, 0),
#   'duration': datetime.timedelta(4, 64800),
#   'pressure': 950.0,
#   'wind_velocity': 80.0,
#   'area1': 150.0,
#   'area2': 370.0,
#   'moving': 2494.0,
#   'mean_velocity': 21.9,
#   'ACE': 65550.0}]
